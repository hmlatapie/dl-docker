# %% [markdown]
# # Displaying Video in IPython Notebook

# %%
# Import the required modules
# %pylab inline 
import cv2
from IPython.display import clear_output
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def displayVideo(capture):
    # Put the code in try-except statements
    # Catch the keyboard exception and 
    # release the camera device and 
    # continue with the rest of code.
    vid = cv2.VideoCapture(capture)
    try:
        while(True):
            # Capture frame-by-frame
            ret, frame = vid.read()
            if not ret:
                # Release the Video Device if ret is false
                vid.release()
                # Message to be displayed after releasing the device
                print "Released Video Resource"
                break
            # Convert the image from OpenCV BGR format to matplotlib RGB format
            # to display the image
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # Turn off the axis
            axis('off')
            # Title of the window
            title("Input Stream")
            # Display the frame
            imshow(frame)
            show()
            # Display the frame until new frame is available
            clear_output(wait=True)
    except KeyboardInterrupt:
        # Release the Video Device
        vid.release()
        # Message to be displayed after releasing the device
        print "Released Video Resource"

# %%
#displayVideo("jpgs/image%05d.jpg")
#displayVideo("http://admin:password@192.168.1.8/video/mjpg.cgi")
displayVideo("rtsp://admin:password@192.168.1.8//live1.sdp")
#displayVideo("rtsp://admin:password@192.168.1.8/play1.sdp")
#displayVideo("all_tgx.mp4")
cv2.__version__
# Out:
# Released Video Resource
# '2.4.8'

# %%
frame =imread("jpgs/image00001.jpg")
imshow(frame)

# %%
displayVideo(r'inpipe')
# Out:
# Released Video Resource

# %%
frame =imread("inpipe")
imshow(frame)
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-5-9f660371ea7e> in <module>()
# ----> 1 frame =imread("inpipe")
#       2 imshow(frame)
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in imread(*args, **kwargs)
#    2175 @docstring.copy_dedent(_imread)
#    2176 def imread(*args, **kwargs):
# -> 2177     return _imread(*args, **kwargs)
#    2178
#    2179
#
# /usr/lib/pymodules/python2.7/matplotlib/image.pyc in imread(fname, format)
#    1240
#    1241     if ext not in handlers.iterkeys():
# -> 1242         im = pilread(fname)
#    1243         if im is None:
#    1244             raise ValueError('Only know how to handle extensions: %s; '
#
# /usr/lib/pymodules/python2.7/matplotlib/image.pyc in pilread(fname)
#    1220             # force close the file after reading the image
#    1221             with open(fname, "rb") as fh:
# -> 1222                 image = Image.open(fh)
#    1223                 return pil_to_array(image)
#    1224         else:
#
# ...

# %% [markdown]
# # Below is a video of the above code in action.

# %%
# %%html
# <!-- TODO -->
# <iframe width="560" height="315" src="https://www.youtube.com/embed/2TT1EKPV_hc" frameborder="0" allowfullscreen></iframe>
